# %% [markdown]
# <a href="https://colab.research.google.com/github/giavonnadonati/Data_Science/blob/main/Donati_Hahn_Stats_2023_Lab_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Stats Notebook Lab #4

# %%
import numpy as np
import matplotlib.pyplot as plt
#importing software

# %%
x = np.array([1,2,3,4])
#making array of all numbers

# %%
# population

# %%
np.sum(x)
#sum of all numbers
# Out:
# 10

# %%
x.shape[0]
# Out:
# 4

# %%
np.sum(x)/x.shape[0]
# sum/shape=10/4=2.5
# Out:
# 2.5

# %%
def mean(x):
    return np.sum(x)/x.shape[0]
  #mean is value of sum divided by shape= 2.5

# %%
mean(x)
# Out:
# 2.5

# %%
x
#defining x as previously defined
# Out:
# array([1, 2, 3, 4])

# %%
x - mean(x)
#values of array- mean(2.5)=values displayed
# Out:
# array([-1.5, -0.5,  0.5,  1.5])

# %%
(x - mean(x))**2
#squaring x-mean(x)
# Out:
# array([2.25, 0.25, 0.25, 2.25])

# %%
 def var(x):
    return mean((x - mean(x))**2)
  #deifing var(x) as the mean(2.5) times x-mean(x) squared

# %%
def std(x):
    return np.sqrt(var(x))
 # defining values as square root of var(x)

# %%
mean(x)
# Out:
# 2.5

# %%
var(x)
# Out:
# 1.25

# %%
std(x)
#square root of var(x)
# Out:
# 1.118033988749895

# %% [markdown]
# ### Random Number Generator

# %% [markdown]
# $y=mx+b$

# %%
m = 75                 # multiplier
b = 74                 # increment
n = 65537              # modulus

# %%
x = 58      # seed value

# %%
X = np.zeros(50000,)
#defining X

# %%
x = (m * x + b) % n
#defining x

# %%
for i in range(X.shape[0]):

    x = (m * x + b) % n
    
    X[i] = x
    #defining i in range

# %%
X
#defining X as zeros up to 5000
# Out:
# array([ 4189., 52101., 40966., ..., 26762., 41114.,  3385.])

# %%
X /= np.max(X)

# %%
plt.plot(X[:100],'.')
#plotting X 100 times

# %%
plt.hist(X);
#histogram of plot of X

# %%
plt.hist(X,100);
#plotting X 100 times

# %%
X
# Out:
# array([0.06392004, 0.7950103 , 0.62510109, ..., 0.40836194, 0.62735943,
#        0.05165179])

# %%
X
# Out:
# array([0.06392004, 0.7950103 , 0.62510109, ..., 0.40836194, 0.62735943,
#        0.05165179])

# %%
X
# Out:
# array([0.06392004, 0.7950103 , 0.62510109, ..., 0.40836194, 0.62735943,
#        0.05165179])

# %% [markdown]
# ### Random Numbers

# %%
X = np.random.random(50000,)
#random samples up to 50000

# %%
X
# Out:
# array([0.40011306, 0.38985632, 0.39471291, ..., 0.55423349, 0.27416936,
#        0.13063618])

# %%
plt.hist(X,100);
#creating histogram

# %%
np.random.random()
# Out:
# 0.9606391027915542

# %%
r = np.random.random()
#defining r

# %%
r
# Out:
# 0.9739937011371627

# %%
r = np.random.randint(1,10)
#gives random integer up to 10

# %%
r
# Out:
# 6

# %%
r = np.random.randint(0,3,size=(1))
# random integer 0 to 3, size 1

# %%
r[0]
# Out:
# 0

# %%
game = ['rock', 'paper', 'scissors']

# %%
game[r[0]]
#runs game of r[0]
# Out:
# 'rock'

# %%
p1 = np.random.randint(0,3,size=(1))[0]
p2 = np.random.randint(0,3,size=(1))[0]
# defines p1 and p2 as random integers as 0 to 3

# %%
p1,p2
# Out:
# (1, 0)

# %%
p1 = np.random.randint(0,3,size=(1))[0]
p2 = np.random.randint(0,3,size=(1))[0]
game[p1],game[p2]
#defines game as both p1 and p2
# Out:
# ('scissors', 'paper')

# %%
import numpy as np
#imports software

# %%
np.random.randn()
# random number
# Out:
# -0.37945352571246965

# %%
numbers  = np.random.randn(2,4)
#defines numbers as random number 2 to 4

# %%
numbers.shape
# Out:
# (2, 4)

# %%
numbers = numbers.reshape(-1)
#defines numbers

# %%
numbers.shape
# Out:
# (8,)

# %%
# numbers= np.array([1,2,2,3,3,3,4,4,4,4])

# %%
numbers = np.random.randn(100000,)
#redefines numbers

# %%
numbers.shape
# Out:
# (100000,)

# %%
plt.hist(numbers,100);
#defines histogram as numbers to 100

# %%
numbers = np.random.rand(1000000,)

# %%
plt.hist(numbers,100);
#plots histogram as numbers to 100

# %%
np.random.seed(12345)
data = np.random.randn(2, 100)

plt.figure(1, figsize=(9, 9))


plt.subplot(2,2,1)
plt.hist(data[0])

plt.subplot(2,2,2)
plt.scatter(data[0], data[1])

plt.subplot(2,2,3)
plt.plot(data[0], data[1])

plt.subplot(2,2,4)
plt.hist2d(data[0], data[1])

plt.show()
#plotting histogram, scatter,regular, and pixel histogram with data(=np.random.randn(2, 100))

# %% [markdown]
# Normal Dist Data

# %%
x = 50*np.random.randn(10000)
#defining x as 50*random number up to 10000

# %%
plt.hist(x);

# %%
x = np.random.rand(1000,)

# %%
plt.hist(x**2);
#plot histogram as x^2

# %%
mu = 100  # mean of distribution
sigma = 15  # standard deviation of distribution
x = mu + sigma * np.random.randn(10000)
#defines x as mean of distribution * standard deviation * random number up to 10000

# %%
n,bins,patches = plt.hist(x)
# define n, bins, patches

# %%
bins
# Out:
# array([ 47.67401067,  58.75290006,  69.83178945,  80.91067884,
#         91.98956823, 103.06845762, 114.14734702, 125.22623641,
#        136.3051258 , 147.38401519, 158.46290458])

# %%
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) * np.exp(-0.5 * (1 / sigma * (bins - mu))**2))
plt.plot(y)
#defines y

# %%
num_bins = 50
n,bins,patches = plt.hist(x, num_bins, density=1)
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) * np.exp(-0.5 * (1 / sigma * (bins - mu))**2))
plt.plot(bins,y)

# %%
def mean(x):
    return np.sum(x)/x.shape[0]
    #defines mean as sum of x/ x.shape[0]

# %%
def var(x):
    return mean((x - mean(x))**2)
  #defines var(x)

# %%
def std(x):
    return np.sqrt(var(x))
    #defines std(x)

# %%
mean(x)
#finds mean of x
# Out:
# 100.08288406198832

# %%
std(x)
#finds std(standard deviation) of x
# Out:
# 14.975014354444243

# %% [markdown]
# # Normal Random Number Generator

# %%
#CDF PDF

# %%
x = np.linspace(-10,10,100)
y = 2.71**(-x**2)
plt.plot(x,y)
#defines x as 1-- guesses from -10 to 10, y , and plots x on x axis, y on y-axiss

# %% [markdown]
# $e^{-x^2}$

# %% [markdown]
# ![alt text](https://wikimedia.org/api/rest_v1/media/math/render/svg/4abaca87a10ecfa77b5a205056523706fe6c9c3f)

# %%
def normal_pdf(x,mu,sigma):
  
  return (1/(np.sqrt(2*np.pi*sigma**2)))*np.exp((-(x-mu)**2)/(2*sigma**2))
#defines normal_pdf

# %%
x = np.linspace(-6,6,1000)
# x as 1000 guess from -6 to 6

# %%
mu = 0
#mean of distribution is 0

# %%
sigma = 1
#standard deviation is 1

# %%
pdf = normal_pdf(x,mu,sigma) #Use Normal for demo, replace with custom function pdf

# %%
plt.plot(x,pdf,'.')
plt.plot(x,y,'g.')
#plotting x,pdf, with dotted line, and x,y with green dotted line
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-202-cd99fbb22699> in <module>
#       1 plt.plot(x,pdf,'.')
# ----> 2 plt.plot(x,y,'g.')
#       3 #plotting x,pdf, with dotted line, and x,y with green dotted line
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2759 @docstring.copy(Axes.plot)
#    2760 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
#    2763         is not None else {}), **kwargs)
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1645         """
#    1646         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# ...

# %%
def partial_sums(x):

  y = np.zeros(x.shape)
  
  for n in range(x.shape[0]):
    
    y[n] = np.sum(x[0:n])
    
  y = y / np.max(y)
    
  return y
  #if y=y/np.max(y), return y

# %%
cdf = partial_sums(pdf)
#defines cdf

# %%
plt.plot(x,cdf,'.');
#plots x to cdf with dotted line

# %%
d_cdf = cdf[1:] - cdf[0:-1] #Demo to show that the diff of the cdf gives you back the pdf
plt.plot(x[1:],d_cdf,'.');  #Not required for sampling

# %%
plt.plot(cdf,x,'.');
#plots cdf and x with dotted

# %%
def find_nearest(array, value):

  idx = np.argmin(np.abs(array - value))
  
  return idx
  #defines find_nearest as index

# %%
find_nearest(cdf, 0.1)
#
# Out:
# 393

# %%
x[393]
# Out:
# -1.2792792792792795

# %%
xr = np.random.random((10000,))
# defines xr

# %%
w = np.zeros(xr.shape[0])

for i in range(xr.shape[0]):
  
  w[i] = x[find_nearest(cdf, xr[i])]
  # defines w for i in rande (xr.shape[0]) as w within i

# %%
w.shape
# Out:
# (10000,)

# %%
plt.hist(w,50);

# %%
num_bins = 50
n,bins,patches = plt.hist(w, num_bins, density=1)
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) * np.exp(-0.5 * (1 / sigma * (bins - mu))**2))
plt.plot(bins,y)

# %% [markdown]
# # Random Color

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
z = np.random.randint(0,255,size=(1,1,3))
# defines z as random integers from 0 to 255

# %%
z
# Out:
# array([[[143,  35, 173]]])

# %%
z = np.random.randint(0,255,size=(10,10,3))\
# random integers 0 to 255

# %%
plt.imshow(z)
#plots with z to integer

# %%
z = np.zeros((10,10,3))
#defines z as zeros from 10 to 10 with 3 guess

# %%
z.shape
# Out:
# (10, 10, 3)

# %%
plt.imshow(z)

# %%
z = 0*np.ones((10,10,3))
# defines z as 0 as ones from 10 to 10 with 3 guesses

# %%
plt.imshow(z)
#plotting imshow with z as variable

# %%
z = 255*np.ones((10,10,3))

# %%
plt.imshow(z)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
z = np.ones((10,10,3))

z[:,:,0] = 1
z[:,:,1] = 0
z[:,:,2] = 0

plt.imshow(z)
#plots red

# %%
z = np.ones((10,10,3))

z[:,:,0] = 0
z[:,:,1] = 1
z[:,:,2] = 0

plt.imshow(z)
#plots green

# %%
z = np.ones((10,10,3))

z[:,:,0] = 0
z[:,:,1] = 0
z[:,:,2] = 1

plt.imshow(z)
#plots blue

# %%
plt.hist(np.random.randn(1000,)/6 + 1/2)
#plots histogram random numbers up to 1000/6+1/2
# Out:
# (array([  4.,  18.,  68., 134., 202., 246., 172.,  99.,  50.,   7.]),
#  array([-0.02876906,  0.07080579,  0.17038065,  0.2699555 ,  0.36953036,
#          0.46910521,  0.56868007,  0.66825492,  0.76782978,  0.86740463,
#          0.96697949]),
#  <a list of 10 Patch objects>)

# %%
for _ in range(100):
    z = np.ones((10,10,3))

    r = np.random.randn()/6 + 1/2
    g = np.random.randn()/6 + 1/2
    b = np.random.randn()/6 + 1/2

    print(r,g,b)

    z[:,:,0] = r
    z[:,:,1] = g
    z[:,:,2] = b

    plt.imshow(z);
    # defines z as ones from 10 to 10 with 3 guesses 
    # gives values for red green and blue as a random number divided by 6 +1/2
# Out:
# 0.9609177416769572 0.6548405235887911 0.35400260809422884
# 0.5851527760921911 0.23751437350707644 0.4664648927801337
# 0.6489153467942492 0.4000956483525077 0.5676128687153061
# 0.6438505486081006 0.49993700834733945 0.4655419700548276
# 0.31468626927418775 0.5034695466676606 0.6893076530022498
# 0.6972781373948941 0.3257249570674138 0.5900173473422389
# 0.5322023740567748 0.3011483823822023 0.5877618365102513
# 0.27484745292214074 0.5156794613775969 0.5762764172356692
# 0.21600138909597605 0.6253187922978377 0.44659625133077385
# 0.7297288358149904 0.34294038202283084 0.5997058828447125
# 0.7710282341193522 0.5078124205826337 0.649313474844395
# 0.485133512076641 0.7757793126483493 0.5627165049145761
# 0.7055565489975382 0.6456237311846923 0.5710610654490071
# 0.6654707156391391 0.518541520799317 0.6460131789306138
# 0.6595477181869493 0.5161579111500405 0.6974862441506711
# 0.6293368850546737 0.5171309761563583 0.3022854783531179
# ...

# %%
for i in range(100):

    z = np.ones((10,10,3))

    r = np.random.rand()
    g = np.random.rand()
    b = np.random.rand()

    print(r,g,b)

    z[:,:,0] = r
    z[:,:,1] = g
    z[:,:,2] = b

    plt.imshow(z);
    plt.show()
    #defines i for range up to 100 as ones from 10 to 10 with 3 guesses
# Out:
# 0.45913291353930186 0.3634420891291348 0.48986099886856616
# 0.2811208072718172 0.8001442491745896 0.4762338203293639
# 0.0632038567862202 0.5918013469366012 0.5950782037334417
# 0.29082549766812205 0.6518334665604232 0.1273750908819553
# 0.17473541904322043 0.1625758042573625 0.4665254294470388
# 0.41474255272795624 0.5494902866888689 0.37036637062325073
# 0.6728559851888738 0.35784001384090103 0.5102746471736584
# 0.5545003736546259 0.2661581114998104 0.5847130544907204
# 0.7935980336050439 0.56820677885883 0.8022041484334256
# 0.8341419855550308 0.1040346196161751 0.12842114604400545
# 0.7390669215095188 0.7884067364243924 0.6591134504760601
# 0.035858677526867444 0.8172977949335123 0.4860215443717053
# 0.3114426043019052 0.12767270862003743 0.16069777062727297
# 0.24252963664058147 0.1953619642816401 0.8068266671542773
# 0.6598921805376493 0.4993543394201063 0.45893354434710854
# 0.8104157842927029 0.9515519421465677 0.430655677128167
# ...

# %%
z1 = np.ones((10,10,3))
z1[:,:,0] = np.random.rand()
z1[:,:,1] = np.random.rand()
z1[:,:,2] = np.random.rand()

z2 = np.ones((10,10,3))
z2[:,:,0] = np.random.rand()
z2[:,:,1] = np.random.rand()
z2[:,:,2] = np.random.rand()

zavg = (z1+z2)/2

z1a = (z1+zavg)/2
z2a = (z2+zavg)/2

z3 = np.hstack((z1,z1a,zavg,z2a,z2))

plt.imshow(z3);
plt.show()

# %%
for i in range(100):
    
    z1 = np.ones((10,10,3))
    z1[:,:,0] = np.random.rand()
    z1[:,:,1] = np.random.rand()
    z1[:,:,2] = np.random.rand()

    z2 = np.ones((10,10,3))
    z2[:,:,0] = np.random.rand()
    z2[:,:,1] = np.random.rand()
    z2[:,:,2] = np.random.rand()

    zavg = (z1+z2)/2

    z1a = (z1+zavg)/2
    z2a = (z2+zavg)/2

    z3 = np.hstack((z1,z1a,zavg,z2a,z2))

    plt.imshow(z3);
    plt.show()
    #gives average of z  as z1 and z2 avergae', haystacks z3/

# %%
for i in range(100):
    
    z1 = np.ones((10,10,3))
    z2 = np.ones((10,10,3))

    r = np.random.rand()
    g = np.random.rand()
    b = np.random.rand()

    z1[:,:,0] = r
    z1[:,:,1] = g
    z1[:,:,2] = b
    
    z2[:,:,0] = 1-r
    z2[:,:,1] = 1-g
    z2[:,:,2] = 1-b

    z3 = np.hstack((z1,z2))

    plt.imshow(z3);
    plt.show()
    #defines z1 as colors, and z2 as 1 minus colors for color scale

# %% [markdown]
# https://lospec.com/palette-list

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import matplotlib
import imageio
from PIL import Image

def get_colors_lospec(url):
    im = imageio.imread(url)
    rgb_list = (im/255)[0,:,0:3]
    float_list = list(np.linspace(0,1,len(rgb_list)))    
    cdict = dict()
    for num, col in enumerate(['red', 'green', 'blue']):
        col_list = [[float_list[i], rgb_list[i][num], rgb_list[i][num]] for i in range(len(float_list))]
        cdict[col] = col_list
    cmp = mcolors.LinearSegmentedColormap('my_cmp', segmentdata=cdict, N=256)
    return cmp

# %%
url = 'https://lospec.com/palette-list/agb-32x.png'

# %%
url = 'https://lospec.com/palette-list/agb-1x.png'

# %%
url = 'https://lospec.com/palette-list/moondrom-1x.png'

# %%
im = imageio.imread(url)

# %%
plt.imshow(im);

# %%
z = np.random.randint(0,255,size=(10,10))

# %%
plt.imshow(z, cmap=get_colors_lospec(url))
plt.colorbar();
#givescolor baer

# %%
x, y = np.mgrid[-5:5:0.05, -5:5:0.05]
z = np.sqrt(x**2 + y**2)

plt.imshow(z, cmap=get_colors_lospec(url));
plt.show()
#gives color wheel

# %%
x, y = np.mgrid[-5:5:0.05, -5:5:0.05]
z = np.sin(3*y)

plt.imshow(z, cmap=get_colors_lospec(url));
plt.show()
#gives color stripes

# %%
x, y = np.mgrid[-5:5:0.05, -5:5:0.05]
z = np.sin(3*y)*np.sin(3*x)

plt.imshow(z, cmap=get_colors_lospec(url));
plt.show()
